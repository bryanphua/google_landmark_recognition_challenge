# %% [markdown]
# Test Image

# %%
from IPython.display import Image 
import imghdr
path = '/mount_point/home/ubuntu/.kaggle/competitions/landmark-recognition-challenge/data/images/test/0001623c6d808702.jpg'
print(imghdr.what(path))
print(type(imghdr.what(path)))
Image(filename=path)
# Out:
# jpeg
# <class 'str'>

# %% [raw]
# 11300 0.04353928
# 10108 0.031749163
# 10414 0.020926166
# 10042 0.018070325
# 1211 0.01652528

# %%
path = '/mount_point/home/ubuntu/.kaggle/competitions/landmark-recognition-challenge/data/images/train/11300/13970ecc07414a8b.jpg'

Image(filename=path)

# %%
path = '/mount_point/home/ubuntu/.kaggle/competitions/landmark-recognition-challenge/data/images/train/10108/151c30e353863a70.jpg'

Image(filename=path)

# %% [raw]
# TEST IMAGE 2

# %%
path = '/mount_point/home/ubuntu/.kaggle/competitions/landmark-recognition-challenge/data/images/train/11300/13970ecc07414a8b.jpg'

Image(filename=path)
